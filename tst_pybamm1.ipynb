# %%
import pybamm
import matplotlib.pyplot as plt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pybamm
#   Downloading pybamm-23.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 47.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from pybamm) (1.22.4)
# Requirement already satisfied: scipy>=1.3 in /usr/local/lib/python3.10/dist-packages (from pybamm) (1.10.1)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from pybamm) (1.5.3)
# Collecting anytree>=2.4.3 (from pybamm)
#   Downloading anytree-2.8.0-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: autograd>=1.2 in /usr/local/lib/python3.10/dist-packages (from pybamm) (1.5)
# Collecting scikit-fem>=0.2.0 (from pybamm)
#   Downloading scikit_fem-8.0.0-py3-none-any.whl (157 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.8/157.8 kB 19.2 MB/s eta 0:00:00
# Collecting casadi>=3.6.0 (from pybamm)
#   Downloading casadi-3.6.3-cp310-none-manylinux2014_x86_64.whl (67.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 MB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: imageio>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from pybamm) (2.25.1)
# Collecting importlib-metadata (from pybamm)
#   Downloading importlib_metadata-6.6.0-py3-none-any.whl (22 kB)
# Collecting pybtex>=0.24.0 (from pybamm)
#   Downloading pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 kB 45.4 MB/s eta 0:00:00
# Requirement already satisfied: sympy>=1.8 in /usr/local/lib/python3.10/dist-packages (from pybamm) (1.11.1)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from pybamm) (2022.12.0)
# Collecting bpx (from pybamm)
#   Downloading bpx-0.2.0-py2.py3-none-any.whl (8.5 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pybamm) (4.65.0)
# Requirement already satisfied: matplotlib>=2.0 in /usr/local/lib/python3.10/dist-packages (from pybamm) (3.7.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from anytree>=2.4.3->pybamm) (1.16.0)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from autograd>=1.2->pybamm) (0.18.3)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio>=2.9.0->pybamm) (8.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0->pybamm) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0->pybamm) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0->pybamm) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0->pybamm) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0->pybamm) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0->pybamm) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0->pybamm) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->pybamm) (2022.7.1)
# Requirement already satisfied: PyYAML>=3.01 in /usr/local/lib/python3.10/dist-packages (from pybtex>=0.24.0->pybamm) (6.0)
# Collecting latexcodec>=1.0.4 (from pybtex>=0.24.0->pybamm)
#   Downloading latexcodec-2.0.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.8->pybamm) (1.3.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from bpx->pybamm) (1.10.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->pybamm) (3.15.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->bpx->pybamm) (4.5.0)
# Installing collected packages: latexcodec, importlib-metadata, casadi, anytree, scikit-fem, pybtex, bpx, pybamm
# Successfully installed anytree-2.8.0 bpx-0.2.0 casadi-3.6.3 importlib-metadata-6.6.0 latexcodec-2.0.1 pybamm-23.4.1 pybtex-0.24.0 scikit-fem-8.0.0

# %%
def fast():  # function to run discharge and charge cycles
    print('Fast Cycle Launched Successfully !!')
    pybamm.set_logging_level("NOTICE")  # To see updates after each steps of charging and discharging
    # solution  = [] # blank array defined for storing solutions after simulation
    params = pybamm.ParameterValues("Chen2020")  # calling parameters of chen from pybamm
    params.update({"SEI kinetic rate constant [m.s-1]": 1e-14,  # updating rate const from -15to-14 for easy calculation
                   "Ambient temperature [K]": 298})
    spm = pybamm.lithium_ion.SPM(  # Single Particle Model (SPM) is selected with sub models given below
                                {"SEI": "ec reaction limited",          # capacity fade model
                                 "thermal": "lumped",                   # thermal model
                                 "SEI porosity change": "true",         # porosity change model
                                 "SEI film resistance": "distributed"}  # film resistance model
                                )
    experiment1 = pybamm.Experiment([  # defining experiment steps for first or initial cycle
    ("discharge at 0.8 A until 2.48V",  # discharging by default
     "rest for 15 minute",
     "charge at 12A until 4.2V",
     "hold at 4.2V until C/50",
     "rest for 15 minute")])
    sim1 = pybamm.Simulation(spm, experiment=experiment1, parameter_values=params)
    # giving model, experiment and parameters to simulation
    sol1 = sim1.solve()
    # solver=pybamm.CasadiSolver(mode="safe")) #sim1.solve() # solving and writing results to variable sol1
    solution = [sol1]  # writing sol1 to solution array

    for i in range (51) :
        experiment2 = pybamm.Experiment([  # defining experiment steps for first or initial cycle
        ("discharge at 0.8A until 2.48V",  # discharging by default
         "rest for 15 minute",
         f"charge at 12A until 4.2V",
         "hold at 4.2V until C/50",
         "rest for 15 minute")])
        sim2 = pybamm.Simulation(spm, experiment=experiment2, parameter_values=params)
        sol2 = sim2.solve(starting_solution=solution[i])
        solution.append(sol2)
    fig, ax = plt.subplots(2, 1, figsize=(8, 8))
    for sol in solution :
      t = sol["Time [s]"].entries
      V = sol["Terminal voltage [V]"].entries
      I = sol["Current [A]"].entries
      ax[0].plot(t, V, label="Voltage")
      ax[1].plot(t, I, label="Current")

    ax[0].set_xlabel("Time [s]")
    ax[0].set_ylabel("Voltage [V]")
    ax[1].set_xlabel("Time [s]")
    ax[1].set_ylabel("Current [A]")
    ax[0].legend()
    ax[1].legend()
    plt.tight_layout()
    plt.show()

# %%
fast()

# %%
def fast():  # function to run discharge and charge cycles
    print('Fast Cycle Launched Successfully !!')
    pybamm.set_logging_level("NOTICE")  # To see updates after each steps of charging and discharging
    # solution  = [] # blank array defined for storing solutions after simulation
    params = pybamm.ParameterValues("Chen2020")  # calling parameters of chen from pybamm
    params.update({"SEI kinetic rate constant [m.s-1]": 1e-14,  # updating rate const from -15to-14 for easy calculation
                   "Ambient temperature [K]": 298})
    spm = pybamm.lithium_ion.SPM(  # Single Particle Model (SPM) is selected with sub models given below
                                {"SEI": "ec reaction limited",          # capacity fade model
                                 "thermal": "lumped",                   # thermal model
                                 "SEI porosity change": "true",         # porosity change model
                                 "SEI film resistance": "distributed"}  # film resistance model
                                )
    experiment1 = pybamm.Experiment([  # defining experiment steps for first or initial cycle
    ("discharge at 0.8 A until 2.48V",  # discharging by default
     "rest for 15 minute",
     "charge at 12A until 4.2V",
     "hold at 4.2V until C/50",
     "rest for 15 minute")])
    sim1 = pybamm.Simulation(spm, experiment=experiment1, parameter_values=params)
    # giving model, experiment and parameters to simulation
    sol1 = sim1.solve()
    # solver=pybamm.CasadiSolver(mode="safe")) #sim1.solve() # solving and writing results to variable sol1
    solution = [sol1]  # writing sol1 to solution array

    for i in range (2) :
        # experiment2 = pybamm.Experiment([  # defining experiment steps for first or initial cycle
        # ("discharge at 0.8A until 2.48V",  # discharging by default
        #  "rest for 15 minute",
        #  f"charge at 12A until 4.2V",
        #  "hold at 4.2V until C/50",
        #  "rest for 15 minute")])
        sim2 = pybamm.Simulation(spm, experiment=experiment1, parameter_values=params)
        sol2 = sim2.solve(starting_solution=solution[i])
        solution.append(sol2)
    fig, ax = plt.subplots(2, 1, figsize=(8, 8))
    for sol in solution :
      t = sol["Time [s]"].entries
      V = sol["Terminal voltage [V]"].entries
      I = sol["Current [A]"].entries
      ax[0].plot(t, V, label="Voltage")
      ax[1].plot(t, I, label="Current")

    ax[0].set_xlabel("Time [s]")
    ax[0].set_ylabel("Voltage [V]")
    ax[1].set_xlabel("Time [s]")
    ax[1].set_ylabel("Current [A]")
    ax[0].legend()
    ax[1].legend()
    plt.tight_layout()
    plt.show()

# %%
fast()
# Out:
# Fast Cycle Launched Successfully !!
# 2023-05-18 20:13:29.159 - [NOTICE] callbacks.on_cycle_start(172): Cycle 1/1 (1.727 ms elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 1/1 (1.727 ms elapsed) --------------------
# 2023-05-18 20:13:29.163 - [NOTICE] callbacks.on_step_start(180): Cycle 1/1, step 1/5: discharge at 0.8 A until 2.48V
# NOTICE:pybamm.logger:Cycle 1/1, step 1/5: discharge at 0.8 A until 2.48V
# 2023-05-18 20:13:29.312 - [NOTICE] callbacks.on_step_start(180): Cycle 1/1, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 1/1, step 2/5: rest for 15 minute
# 2023-05-18 20:13:29.359 - [NOTICE] callbacks.on_step_start(180): Cycle 1/1, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 1/1, step 3/5: charge at 12A until 4.2V
# 2023-05-18 20:13:29.448 - [NOTICE] callbacks.on_step_start(180): Cycle 1/1, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 1/1, step 4/5: hold at 4.2V until C/50
# 2023-05-18 20:13:29.581 - [NOTICE] callbacks.on_step_start(180): Cycle 1/1, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 1/1, step 5/5: rest for 15 minute
# 2023-05-18 20:13:30.135 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 977.310 ms
# NOTICE:pybamm.logger:Finish experiment simulation, took 977.310 ms
# 2023-05-18 20:13:31.578 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2/2 (221.271 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2/2 (221.271 us elapsed) --------------------
# 2023-05-18 20:13:31.585 - [NOTICE] callbacks.on_step_start(180): Cycle 2/2, step 1/5: discharge at 0.8 A until 2.48V
# NOTICE:pybamm.logger:Cycle 2/2, step 1/5: discharge at 0.8 A until 2.48V
# 2023-05-18 20:13:31.818 - [NOTICE] callbacks.on_step_start(180): Cycle 2/2, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 2/2, step 2/5: rest for 15 minute
# 2023-05-18 20:13:31.898 - [NOTICE] callbacks.on_step_start(180): Cycle 2/2, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 2/2, step 3/5: charge at 12A until 4.2V
# 2023-05-18 20:13:32.023 - [NOTICE] callbacks.on_step_start(180): Cycle 2/2, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 2/2, step 4/5: hold at 4.2V until C/50
# 2023-05-18 20:13:32.233 - [NOTICE] callbacks.on_step_start(180): Cycle 2/2, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 2/2, step 5/5: rest for 15 minute
# 2023-05-18 20:13:33.159 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 1.582 s
# NOTICE:pybamm.logger:Finish experiment simulation, took 1.582 s
# 2023-05-18 20:13:34.945 - [NOTICE] callbacks.on_cycle_start(172): Cycle 3/3 (222.241 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 3/3 (222.241 us elapsed) --------------------
# 2023-05-18 20:13:34.952 - [NOTICE] callbacks.on_step_start(180): Cycle 3/3, step 1/5: discharge at 0.8 A until 2.48V
# NOTICE:pybamm.logger:Cycle 3/3, step 1/5: discharge at 0.8 A until 2.48V
# 2023-05-18 20:13:35.390 - [NOTICE] callbacks.on_step_start(180): Cycle 3/3, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 3/3, step 2/5: rest for 15 minute
# 2023-05-18 20:13:35.460 - [NOTICE] callbacks.on_step_start(180): Cycle 3/3, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 3/3, step 3/5: charge at 12A until 4.2V
# 2023-05-18 20:13:35.582 - [NOTICE] callbacks.on_step_start(180): Cycle 3/3, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 3/3, step 4/5: hold at 4.2V until C/50
# 2023-05-18 20:13:35.789 - [NOTICE] callbacks.on_step_start(180): Cycle 3/3, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 3/3, step 5/5: rest for 15 minute
# 2023-05-18 20:13:36.747 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 1.802 s
# NOTICE:pybamm.logger:Finish experiment simulation, took 1.802 s

# %%
def fast():  # function to run discharge and charge cycles
    print('Fast Cycle Launched Successfully !!')
    pybamm.set_logging_level("NOTICE")  # To see updates after each steps of charging and discharging
    # solution  = [] # blank array defined for storing solutions after simulation
    params = pybamm.ParameterValues("Chen2020")  # calling parameters of chen from pybamm
    params.update({"SEI kinetic rate constant [m.s-1]": 1e-14,  # updating rate const from -15to-14 for easy calculation
                   "Ambient temperature [K]": 298})
    spm = pybamm.lithium_ion.SPM(  # Single Particle Model (SPM) is selected with sub models given below
                                {"SEI": "ec reaction limited",          # capacity fade model
                                 "thermal": "lumped",                   # thermal model
                                 "SEI porosity change": "true",         # porosity change model
                                 "SEI film resistance": "distributed"}  # film resistance model
                                )
    experiment1 = pybamm.Experiment([  # defining experiment steps for first or initial cycle
    ("discharge at 0.8 A until 2.48V",  # discharging by default
     "rest for 15 minute",
     "charge at 12A until 4.2V",
     "hold at 4.2V until C/50",
     "rest for 15 minute")])
    sim1 = pybamm.Simulation(spm, experiment=experiment1, parameter_values=params)
    # giving model, experiment and parameters to simulation
    sol1 = sim1.solve()
    # solver=pybamm.CasadiSolver(mode="safe")) #sim1.solve() # solving and writing results to variable sol1
    solution = [sol1]  # writing sol1 to solution array

    for i in range (2) :
        experiment2 = pybamm.Experiment([  # defining experiment steps for first or initial cycle
        ("discharge at 0.8A until 2.48V",  # discharging by default
         "rest for 15 minute",
         f"charge at 12A until 4.2V",
         "hold at 4.2V until C/50",
         "rest for 15 minute")])
        sim2 = pybamm.Simulation(spm, experiment=experiment2, parameter_values=params)
        sol2 = sim2.solve(starting_solution=solution[i])
        solution.append(sol2)

    # fig, ax = plt.subplots(2, 1, figsize=(8, 8))
    # for sol in solution :
    #   t = sol["Time [s]"].entries
    #   V = sol["Terminal voltage [V]"].entries
    #   I = sol["Current [A]"].entries
    #   ax[0].plot(t, V, label="Voltage")
    #   ax[1].plot(t, I, label="Current")

    # ax[0].set_xlabel("Time [s]")
    # ax[0].set_ylabel("Voltage [V]")
    # ax[1].set_xlabel("Time [s]")
    # ax[1].set_ylabel("Current [A]")
    # ax[0].legend()
    # ax[1].legend()
    # plt.tight_layout()
    # plt.show()

    fig, ax = plt.subplots(2, 1, figsize=(8, 8))
    total_time = 0
    for sol in solution:
      t = sol["Time [s]"].entries + total_time
      V = sol["Terminal voltage [V]"].entries
      I = sol["Current [A]"].entries
      total_time += sol["Time [s]"].entries[-1]
      ax[0].plot(t, V, label="Voltage")
      ax[1].plot(t, I, label="Current")

    ax[0].set_xlabel("Time [s]")
    ax[0].set_ylabel("Voltage [V]")
    ax[1].set_xlabel("Time [s]")
    ax[1].set_ylabel("Current [A]")
    ax[0].legend()
    ax[1].legend()
    plt.tight_layout()
    plt.show()

# %%
fast()
# Out:
# Fast Cycle Launched Successfully !!
# 2023-05-18 20:17:01.606 - [NOTICE] callbacks.on_cycle_start(172): Cycle 1/1 (276.883 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 1/1 (276.883 us elapsed) --------------------
# 2023-05-18 20:17:01.617 - [NOTICE] callbacks.on_step_start(180): Cycle 1/1, step 1/5: discharge at 0.8 A until 2.48V
# NOTICE:pybamm.logger:Cycle 1/1, step 1/5: discharge at 0.8 A until 2.48V
# 2023-05-18 20:17:01.750 - [NOTICE] callbacks.on_step_start(180): Cycle 1/1, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 1/1, step 2/5: rest for 15 minute
# 2023-05-18 20:17:01.797 - [NOTICE] callbacks.on_step_start(180): Cycle 1/1, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 1/1, step 3/5: charge at 12A until 4.2V
# 2023-05-18 20:17:01.884 - [NOTICE] callbacks.on_step_start(180): Cycle 1/1, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 1/1, step 4/5: hold at 4.2V until C/50
# 2023-05-18 20:17:01.999 - [NOTICE] callbacks.on_step_start(180): Cycle 1/1, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 1/1, step 5/5: rest for 15 minute
# 2023-05-18 20:17:02.743 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 1.137 s
# NOTICE:pybamm.logger:Finish experiment simulation, took 1.137 s
# 2023-05-18 20:17:03.936 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2/2 (207.304 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2/2 (207.304 us elapsed) --------------------
# 2023-05-18 20:17:03.940 - [NOTICE] callbacks.on_step_start(180): Cycle 2/2, step 1/5: discharge at 0.8A until 2.48V
# NOTICE:pybamm.logger:Cycle 2/2, step 1/5: discharge at 0.8A until 2.48V
# 2023-05-18 20:17:04.081 - [NOTICE] callbacks.on_step_start(180): Cycle 2/2, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 2/2, step 2/5: rest for 15 minute
# 2023-05-18 20:17:04.123 - [NOTICE] callbacks.on_step_start(180): Cycle 2/2, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 2/2, step 3/5: charge at 12A until 4.2V
# 2023-05-18 20:17:04.198 - [NOTICE] callbacks.on_step_start(180): Cycle 2/2, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 2/2, step 4/5: hold at 4.2V until C/50
# 2023-05-18 20:17:04.341 - [NOTICE] callbacks.on_step_start(180): Cycle 2/2, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 2/2, step 5/5: rest for 15 minute
# 2023-05-18 20:17:05.085 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 1.149 s
# NOTICE:pybamm.logger:Finish experiment simulation, took 1.149 s
# 2023-05-18 20:17:06.844 - [NOTICE] callbacks.on_cycle_start(172): Cycle 3/3 (225.371 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 3/3 (225.371 us elapsed) --------------------
# 2023-05-18 20:17:06.848 - [NOTICE] callbacks.on_step_start(180): Cycle 3/3, step 1/5: discharge at 0.8A until 2.48V
# NOTICE:pybamm.logger:Cycle 3/3, step 1/5: discharge at 0.8A until 2.48V
# 2023-05-18 20:17:07.067 - [NOTICE] callbacks.on_step_start(180): Cycle 3/3, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 3/3, step 2/5: rest for 15 minute
# 2023-05-18 20:17:07.131 - [NOTICE] callbacks.on_step_start(180): Cycle 3/3, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 3/3, step 3/5: charge at 12A until 4.2V
# 2023-05-18 20:17:07.254 - [NOTICE] callbacks.on_step_start(180): Cycle 3/3, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 3/3, step 4/5: hold at 4.2V until C/50
# 2023-05-18 20:17:07.468 - [NOTICE] callbacks.on_step_start(180): Cycle 3/3, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 3/3, step 5/5: rest for 15 minute
# 2023-05-18 20:17:08.161 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 1.317 s
# NOTICE:pybamm.logger:Finish experiment simulation, took 1.317 s

# %%
def fast():  # function to run discharge and charge cycles
    print('Fast Cycle Launched Successfully !!')
    pybamm.set_logging_level("NOTICE")  # To see updates after each steps of charging and discharging
    # solution  = [] # blank array defined for storing solutions after simulation
    params = pybamm.ParameterValues("Chen2020")  # calling parameters of chen from pybamm
    params.update({"SEI kinetic rate constant [m.s-1]": 1e-14,  # updating rate const from -15to-14 for easy calculation
                   "Ambient temperature [K]": 298})
    spm = pybamm.lithium_ion.SPM(  # Single Particle Model (SPM) is selected with sub models given below
                                {"SEI": "ec reaction limited",          # capacity fade model
                                 "thermal": "lumped",                   # thermal model
                                 "SEI porosity change": "true",         # porosity change model
                                 "SEI film resistance": "distributed"}  # film resistance model
                                )
    experiment1 = pybamm.Experiment([  # defining experiment steps for first or initial cycle
    ("discharge at 0.8 A until 2.48V",  # discharging by default
     "rest for 15 minute",
     "charge at 12A until 4.2V",
     "hold at 4.2V until C/50",
     "rest for 15 minute")])
    sim1 = pybamm.Simulation(spm, experiment=experiment1, parameter_values=params)
    # giving model, experiment and parameters to simulation
    sol1 = sim1.solve()
    # solver=pybamm.CasadiSolver(mode="safe")) #sim1.solve() # solving and writing results to variable sol1
    solution = [sol1]  # writing sol1 to solution array

    for i in range (2) :
        experiment2 = pybamm.Experiment([  # defining experiment steps for first or initial cycle
        ("discharge at 0.8A until 2.48V",  # discharging by default
         "rest for 15 minute",
         f"charge at 12A until 4.2V",
         "hold at 4.2V until C/50",
         "rest for 15 minute")])
        sim2 = pybamm.Simulation(spm, experiment=experiment2, parameter_values=params)
        sol2 = sim2.solve(starting_solution=solution[i])
        solution.append(sol2)

    colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
    fig, ax = plt.subplots(2, 1, figsize=(8, 8))
    for i, sol in enumerate(solution):
      t = sol["Time [s]"].entries
      V = sol["Terminal voltage [V]"].entries
      I = sol["Current [A]"].entries
      color = colors[i % len(colors)]
      ax[0].plot(t, V, color=color)
      ax[1].plot(t, I, color=color)

    ax[0].set_xlabel("Time [s]")
    ax[0].set_ylabel("Voltage [V]")
    ax[1].set_xlabel("Time [s]")
    ax[1].set_ylabel("Current [A]")
    plt.tight_layout()
    plt.show()

# %%
fast()
# Out:
# Fast Cycle Launched Successfully !!
# 2023-05-18 10:34:53.200 - [NOTICE] callbacks.on_cycle_start(172): Cycle 1/1 (608.586 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 1/1 (608.586 us elapsed) --------------------
# 2023-05-18 10:34:53.212 - [NOTICE] callbacks.on_step_start(180): Cycle 1/1, step 1/5: discharge at 0.8 A until 2.48V
# NOTICE:pybamm.logger:Cycle 1/1, step 1/5: discharge at 0.8 A until 2.48V
# 2023-05-18 10:34:53.432 - [NOTICE] callbacks.on_step_start(180): Cycle 1/1, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 1/1, step 2/5: rest for 15 minute
# 2023-05-18 10:34:53.486 - [NOTICE] callbacks.on_step_start(180): Cycle 1/1, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 1/1, step 3/5: charge at 12A until 4.2V
# 2023-05-18 10:34:53.567 - [NOTICE] callbacks.on_step_start(180): Cycle 1/1, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 1/1, step 4/5: hold at 4.2V until C/50
# 2023-05-18 10:34:53.703 - [NOTICE] callbacks.on_step_start(180): Cycle 1/1, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 1/1, step 5/5: rest for 15 minute
# 2023-05-18 10:34:54.251 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 1.052 s
# NOTICE:pybamm.logger:Finish experiment simulation, took 1.052 s
# 2023-05-18 10:34:55.627 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2/2 (364.593 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2/2 (364.593 us elapsed) --------------------
# 2023-05-18 10:34:55.634 - [NOTICE] callbacks.on_step_start(180): Cycle 2/2, step 1/5: discharge at 0.8A until 2.48V
# NOTICE:pybamm.logger:Cycle 2/2, step 1/5: discharge at 0.8A until 2.48V
# 2023-05-18 10:34:55.799 - [NOTICE] callbacks.on_step_start(180): Cycle 2/2, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 2/2, step 2/5: rest for 15 minute
# 2023-05-18 10:34:56.029 - [NOTICE] callbacks.on_step_start(180): Cycle 2/2, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 2/2, step 3/5: charge at 12A until 4.2V
# 2023-05-18 10:34:56.169 - [NOTICE] callbacks.on_step_start(180): Cycle 2/2, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 2/2, step 4/5: hold at 4.2V until C/50
# 2023-05-18 10:34:56.300 - [NOTICE] callbacks.on_step_start(180): Cycle 2/2, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 2/2, step 5/5: rest for 15 minute
# 2023-05-18 10:34:56.853 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 1.226 s
# NOTICE:pybamm.logger:Finish experiment simulation, took 1.226 s
# 2023-05-18 10:34:58.058 - [NOTICE] callbacks.on_cycle_start(172): Cycle 3/3 (418.103 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 3/3 (418.103 us elapsed) --------------------
# 2023-05-18 10:34:58.066 - [NOTICE] callbacks.on_step_start(180): Cycle 3/3, step 1/5: discharge at 0.8A until 2.48V
# NOTICE:pybamm.logger:Cycle 3/3, step 1/5: discharge at 0.8A until 2.48V
# 2023-05-18 10:34:58.207 - [NOTICE] callbacks.on_step_start(180): Cycle 3/3, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 3/3, step 2/5: rest for 15 minute
# 2023-05-18 10:34:58.266 - [NOTICE] callbacks.on_step_start(180): Cycle 3/3, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 3/3, step 3/5: charge at 12A until 4.2V
# 2023-05-18 10:34:58.354 - [NOTICE] callbacks.on_step_start(180): Cycle 3/3, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 3/3, step 4/5: hold at 4.2V until C/50
# 2023-05-18 10:34:58.484 - [NOTICE] callbacks.on_step_start(180): Cycle 3/3, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 3/3, step 5/5: rest for 15 minute
# 2023-05-18 10:34:59.217 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 1.159 s
# NOTICE:pybamm.logger:Finish experiment simulation, took 1.159 s

# %%
def fast():  # function to run discharge and charge cycles
    print('Fast Cycle Launched Successfully !!')
    pybamm.set_logging_level("NOTICE")  # To see updates after each steps of charging and discharging
    # solution  = [] # blank array defined for storing solutions after simulation
    params = pybamm.ParameterValues("Chen2020")  # calling parameters of chen from pybamm
    params.update({"SEI kinetic rate constant [m.s-1]": 1e-14,  # updating rate const from -15to-14 for easy calculation
                   "Ambient temperature [K]": 298})
    spm = pybamm.lithium_ion.SPM(  # Single Particle Model (SPM) is selected with sub models given below
                                {"SEI": "ec reaction limited",          # capacity fade model
                                 "thermal": "lumped",                   # thermal model
                                 "SEI porosity change": "true",         # porosity change model
                                 "SEI film resistance": "distributed"}  # film resistance model
                                )
    experiment1 = pybamm.Experiment([  # defining experiment steps for first or initial cycle
    ("discharge at 0.8 A until 2.48V",  # discharging by default
     "rest for 15 minute",
     "charge at 12A until 4.2V",
     "hold at 4.2V until C/50",
     "rest for 15 minute")])
    sim1 = pybamm.Simulation(spm, experiment=experiment1, parameter_values=params)
    # giving model, experiment and parameters to simulation
    sol1 = sim1.solve()
    # solver=pybamm.CasadiSolver(mode="safe")) #sim1.solve() # solving and writing results to variable sol1
    solution = [sol1]  # writing sol1 to solution array

    for i in range (15) :
        # experiment2 = pybamm.Experiment([  # defining experiment steps for first or initial cycle
        # ("discharge at 0.8A until 2.48V",  # discharging by default
        #  "rest for 15 minute",
        #  f"charge at 12A until 4.2V",
        #  "hold at 4.2V until C/50",
        #  "rest for 15 minute")])
        # sim2 = pybamm.Simulation(spm, experiment=experiment1, parameter_values=params)
        #!Changed sim to sim1 frm sim2
        sol2 = sim1.solve(starting_solution=solution[i])
        solution.append(sol2)

    fig, ax = plt.subplots(2, 1, figsize=(8, 8))
    
    for sol in solution:
      t = sol["Time [s]"].entries
      V = sol["Terminal voltage [V]"].entries
      I = sol["Current [A]"].entries
      ax[0].plot(t[:496], V[len(V) - 496:])
      ax[1].plot(t[:496], I[len(I) - 496:])

    ax[0].set_xlabel("Time [s]")
    ax[0].set_ylabel("Voltage [V]")
    ax[1].set_xlabel("Time [s]")
    ax[1].set_ylabel("Current [A]")
    plt.tight_layout()
    plt.show()

# %%
fast()
# Out:
# Fast Cycle Launched Successfully !!
# 2023-05-18 21:12:50.022 - [NOTICE] callbacks.on_cycle_start(172): Cycle 1/1 (168.797 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 1/1 (168.797 us elapsed) --------------------
# 2023-05-18 21:12:50.028 - [NOTICE] callbacks.on_step_start(180): Cycle 1/1, step 1/5: discharge at 0.8 A until 2.48V
# NOTICE:pybamm.logger:Cycle 1/1, step 1/5: discharge at 0.8 A until 2.48V
# 2023-05-18 21:12:50.174 - [NOTICE] callbacks.on_step_start(180): Cycle 1/1, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 1/1, step 2/5: rest for 15 minute
# 2023-05-18 21:12:50.218 - [NOTICE] callbacks.on_step_start(180): Cycle 1/1, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 1/1, step 3/5: charge at 12A until 4.2V
# 2023-05-18 21:12:50.297 - [NOTICE] callbacks.on_step_start(180): Cycle 1/1, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 1/1, step 4/5: hold at 4.2V until C/50
# 2023-05-18 21:12:50.417 - [NOTICE] callbacks.on_step_start(180): Cycle 1/1, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 1/1, step 5/5: rest for 15 minute
# 2023-05-18 21:12:50.970 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 948.765 ms
# NOTICE:pybamm.logger:Finish experiment simulation, took 948.765 ms
# 2023-05-18 21:12:50.974 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2/2 (137.664 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2/2 (137.664 us elapsed) --------------------
# 2023-05-18 21:12:50.978 - [NOTICE] callbacks.on_step_start(180): Cycle 2/2, step 1/5: discharge at 0.8 A until 2.48V
# NOTICE:pybamm.logger:Cycle 2/2, step 1/5: discharge at 0.8 A until 2.48V
# 2023-05-18 21:12:51.068 - [NOTICE] callbacks.on_step_start(180): Cycle 2/2, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 2/2, step 2/5: rest for 15 minute
# 2023-05-18 21:12:51.087 - [NOTICE] callbacks.on_step_start(180): Cycle 2/2, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 2/2, step 3/5: charge at 12A until 4.2V
# 2023-05-18 21:12:51.116 - [NOTICE] callbacks.on_step_start(180): Cycle 2/2, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 2/2, step 4/5: hold at 4.2V until C/50
# 2023-05-18 21:12:51.177 - [NOTICE] callbacks.on_step_start(180): Cycle 2/2, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 2/2, step 5/5: rest for 15 minute
# 2023-05-18 21:12:51.569 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 594.958 ms
# NOTICE:pybamm.logger:Finish experiment simulation, took 594.958 ms
# 2023-05-18 21:12:51.575 - [NOTICE] callbacks.on_cycle_start(172): Cycle 3/3 (137.730 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 3/3 (137.730 us elapsed) --------------------
# 2023-05-18 21:12:51.579 - [NOTICE] callbacks.on_step_start(180): Cycle 3/3, step 1/5: discharge at 0.8 A until 2.48V
# NOTICE:pybamm.logger:Cycle 3/3, step 1/5: discharge at 0.8 A until 2.48V
# 2023-05-18 21:12:51.672 - [NOTICE] callbacks.on_step_start(180): Cycle 3/3, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 3/3, step 2/5: rest for 15 minute
# 2023-05-18 21:12:51.691 - [NOTICE] callbacks.on_step_start(180): Cycle 3/3, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 3/3, step 3/5: charge at 12A until 4.2V
# 2023-05-18 21:12:51.717 - [NOTICE] callbacks.on_step_start(180): Cycle 3/3, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 3/3, step 4/5: hold at 4.2V until C/50
# 2023-05-18 21:12:51.772 - [NOTICE] callbacks.on_step_start(180): Cycle 3/3, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 3/3, step 5/5: rest for 15 minute
# 2023-05-18 21:12:52.182 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 607.502 ms
# NOTICE:pybamm.logger:Finish experiment simulation, took 607.502 ms
# 2023-05-18 21:12:52.186 - [NOTICE] callbacks.on_cycle_start(172): Cycle 4/4 (139.397 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 4/4 (139.397 us elapsed) --------------------
# 2023-05-18 21:12:52.190 - [NOTICE] callbacks.on_step_start(180): Cycle 4/4, step 1/5: discharge at 0.8 A until 2.48V
# NOTICE:pybamm.logger:Cycle 4/4, step 1/5: discharge at 0.8 A until 2.48V
# 2023-05-18 21:12:52.280 - [NOTICE] callbacks.on_step_start(180): Cycle 4/4, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 4/4, step 2/5: rest for 15 minute
# 2023-05-18 21:12:52.296 - [NOTICE] callbacks.on_step_start(180): Cycle 4/4, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 4/4, step 3/5: charge at 12A until 4.2V
# 2023-05-18 21:12:52.317 - [NOTICE] callbacks.on_step_start(180): Cycle 4/4, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 4/4, step 4/5: hold at 4.2V until C/50
# 2023-05-18 21:12:52.365 - [NOTICE] callbacks.on_step_start(180): Cycle 4/4, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 4/4, step 5/5: rest for 15 minute
# 2023-05-18 21:12:52.764 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 577.240 ms
# NOTICE:pybamm.logger:Finish experiment simulation, took 577.240 ms
# 2023-05-18 21:12:52.768 - [NOTICE] callbacks.on_cycle_start(172): Cycle 5/5 (140.025 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 5/5 (140.025 us elapsed) --------------------
# 2023-05-18 21:12:52.772 - [NOTICE] callbacks.on_step_start(180): Cycle 5/5, step 1/5: discharge at 0.8 A until 2.48V
# NOTICE:pybamm.logger:Cycle 5/5, step 1/5: discharge at 0.8 A until 2.48V
# 2023-05-18 21:12:52.871 - [NOTICE] callbacks.on_step_start(180): Cycle 5/5, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 5/5, step 2/5: rest for 15 minute
# 2023-05-18 21:12:52.887 - [NOTICE] callbacks.on_step_start(180): Cycle 5/5, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 5/5, step 3/5: charge at 12A until 4.2V
# 2023-05-18 21:12:52.913 - [NOTICE] callbacks.on_step_start(180): Cycle 5/5, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 5/5, step 4/5: hold at 4.2V until C/50
# 2023-05-18 21:12:52.965 - [NOTICE] callbacks.on_step_start(180): Cycle 5/5, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 5/5, step 5/5: rest for 15 minute
# 2023-05-18 21:12:53.616 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 848.049 ms
# NOTICE:pybamm.logger:Finish experiment simulation, took 848.049 ms
# 2023-05-18 21:12:53.623 - [NOTICE] callbacks.on_cycle_start(172): Cycle 6/6 (147.340 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 6/6 (147.340 us elapsed) --------------------
# 2023-05-18 21:12:53.628 - [NOTICE] callbacks.on_step_start(180): Cycle 6/6, step 1/5: discharge at 0.8 A until 2.48V
# NOTICE:pybamm.logger:Cycle 6/6, step 1/5: discharge at 0.8 A until 2.48V
# 2023-05-18 21:12:53.713 - [NOTICE] callbacks.on_step_start(180): Cycle 6/6, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 6/6, step 2/5: rest for 15 minute
# 2023-05-18 21:12:53.728 - [NOTICE] callbacks.on_step_start(180): Cycle 6/6, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 6/6, step 3/5: charge at 12A until 4.2V
# 2023-05-18 21:12:53.750 - [NOTICE] callbacks.on_step_start(180): Cycle 6/6, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 6/6, step 4/5: hold at 4.2V until C/50
# 2023-05-18 21:12:53.808 - [NOTICE] callbacks.on_step_start(180): Cycle 6/6, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 6/6, step 5/5: rest for 15 minute
# 2023-05-18 21:12:54.213 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 589.904 ms
# NOTICE:pybamm.logger:Finish experiment simulation, took 589.904 ms
# 2023-05-18 21:12:54.218 - [NOTICE] callbacks.on_cycle_start(172): Cycle 7/7 (135.758 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 7/7 (135.758 us elapsed) --------------------
# 2023-05-18 21:12:54.224 - [NOTICE] callbacks.on_step_start(180): Cycle 7/7, step 1/5: discharge at 0.8 A until 2.48V
# NOTICE:pybamm.logger:Cycle 7/7, step 1/5: discharge at 0.8 A until 2.48V
# 2023-05-18 21:12:54.313 - [NOTICE] callbacks.on_step_start(180): Cycle 7/7, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 7/7, step 2/5: rest for 15 minute
# 2023-05-18 21:12:54.327 - [NOTICE] callbacks.on_step_start(180): Cycle 7/7, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 7/7, step 3/5: charge at 12A until 4.2V
# 2023-05-18 21:12:54.349 - [NOTICE] callbacks.on_step_start(180): Cycle 7/7, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 7/7, step 4/5: hold at 4.2V until C/50
# 2023-05-18 21:12:54.399 - [NOTICE] callbacks.on_step_start(180): Cycle 7/7, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 7/7, step 5/5: rest for 15 minute
# 2023-05-18 21:12:54.798 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 580.326 ms
# NOTICE:pybamm.logger:Finish experiment simulation, took 580.326 ms
# 2023-05-18 21:12:54.803 - [NOTICE] callbacks.on_cycle_start(172): Cycle 8/8 (130.285 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 8/8 (130.285 us elapsed) --------------------
# 2023-05-18 21:12:54.808 - [NOTICE] callbacks.on_step_start(180): Cycle 8/8, step 1/5: discharge at 0.8 A until 2.48V
# NOTICE:pybamm.logger:Cycle 8/8, step 1/5: discharge at 0.8 A until 2.48V
# 2023-05-18 21:12:54.895 - [NOTICE] callbacks.on_step_start(180): Cycle 8/8, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 8/8, step 2/5: rest for 15 minute
# 2023-05-18 21:12:54.911 - [NOTICE] callbacks.on_step_start(180): Cycle 8/8, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 8/8, step 3/5: charge at 12A until 4.2V
# 2023-05-18 21:12:54.931 - [NOTICE] callbacks.on_step_start(180): Cycle 8/8, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 8/8, step 4/5: hold at 4.2V until C/50
# 2023-05-18 21:12:54.979 - [NOTICE] callbacks.on_step_start(180): Cycle 8/8, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 8/8, step 5/5: rest for 15 minute
# 2023-05-18 21:12:55.381 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 577.353 ms
# NOTICE:pybamm.logger:Finish experiment simulation, took 577.353 ms
# 2023-05-18 21:12:55.385 - [NOTICE] callbacks.on_cycle_start(172): Cycle 9/9 (136.163 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 9/9 (136.163 us elapsed) --------------------
# 2023-05-18 21:12:55.389 - [NOTICE] callbacks.on_step_start(180): Cycle 9/9, step 1/5: discharge at 0.8 A until 2.48V
# NOTICE:pybamm.logger:Cycle 9/9, step 1/5: discharge at 0.8 A until 2.48V
# 2023-05-18 21:12:55.472 - [NOTICE] callbacks.on_step_start(180): Cycle 9/9, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 9/9, step 2/5: rest for 15 minute
# 2023-05-18 21:12:55.489 - [NOTICE] callbacks.on_step_start(180): Cycle 9/9, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 9/9, step 3/5: charge at 12A until 4.2V
# 2023-05-18 21:12:55.512 - [NOTICE] callbacks.on_step_start(180): Cycle 9/9, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 9/9, step 4/5: hold at 4.2V until C/50
# 2023-05-18 21:12:55.563 - [NOTICE] callbacks.on_step_start(180): Cycle 9/9, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 9/9, step 5/5: rest for 15 minute
# 2023-05-18 21:12:55.954 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 568.420 ms
# NOTICE:pybamm.logger:Finish experiment simulation, took 568.420 ms
# 2023-05-18 21:12:55.960 - [NOTICE] callbacks.on_cycle_start(172): Cycle 10/10 (1.102 ms elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 10/10 (1.102 ms elapsed) --------------------
# 2023-05-18 21:12:55.965 - [NOTICE] callbacks.on_step_start(180): Cycle 10/10, step 1/5: discharge at 0.8 A until 2.48V
# NOTICE:pybamm.logger:Cycle 10/10, step 1/5: discharge at 0.8 A until 2.48V
# 2023-05-18 21:12:56.055 - [NOTICE] callbacks.on_step_start(180): Cycle 10/10, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 10/10, step 2/5: rest for 15 minute
# 2023-05-18 21:12:56.070 - [NOTICE] callbacks.on_step_start(180): Cycle 10/10, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 10/10, step 3/5: charge at 12A until 4.2V
# 2023-05-18 21:12:56.094 - [NOTICE] callbacks.on_step_start(180): Cycle 10/10, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 10/10, step 4/5: hold at 4.2V until C/50
# 2023-05-18 21:12:56.146 - [NOTICE] callbacks.on_step_start(180): Cycle 10/10, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 10/10, step 5/5: rest for 15 minute
# 2023-05-18 21:12:56.546 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 586.052 ms
# NOTICE:pybamm.logger:Finish experiment simulation, took 586.052 ms
# 2023-05-18 21:12:56.552 - [NOTICE] callbacks.on_cycle_start(172): Cycle 11/11 (138.334 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 11/11 (138.334 us elapsed) --------------------
# 2023-05-18 21:12:56.557 - [NOTICE] callbacks.on_step_start(180): Cycle 11/11, step 1/5: discharge at 0.8 A until 2.48V
# NOTICE:pybamm.logger:Cycle 11/11, step 1/5: discharge at 0.8 A until 2.48V
# 2023-05-18 21:12:56.646 - [NOTICE] callbacks.on_step_start(180): Cycle 11/11, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 11/11, step 2/5: rest for 15 minute
# 2023-05-18 21:12:56.660 - [NOTICE] callbacks.on_step_start(180): Cycle 11/11, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 11/11, step 3/5: charge at 12A until 4.2V
# 2023-05-18 21:12:56.685 - [NOTICE] callbacks.on_step_start(180): Cycle 11/11, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 11/11, step 4/5: hold at 4.2V until C/50
# 2023-05-18 21:12:56.735 - [NOTICE] callbacks.on_step_start(180): Cycle 11/11, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 11/11, step 5/5: rest for 15 minute
# 2023-05-18 21:12:57.133 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 580.976 ms
# NOTICE:pybamm.logger:Finish experiment simulation, took 580.976 ms
# 2023-05-18 21:12:57.139 - [NOTICE] callbacks.on_cycle_start(172): Cycle 12/12 (172.344 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 12/12 (172.344 us elapsed) --------------------
# 2023-05-18 21:12:57.142 - [NOTICE] callbacks.on_step_start(180): Cycle 12/12, step 1/5: discharge at 0.8 A until 2.48V
# NOTICE:pybamm.logger:Cycle 12/12, step 1/5: discharge at 0.8 A until 2.48V
# 2023-05-18 21:12:57.234 - [NOTICE] callbacks.on_step_start(180): Cycle 12/12, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 12/12, step 2/5: rest for 15 minute
# 2023-05-18 21:12:57.248 - [NOTICE] callbacks.on_step_start(180): Cycle 12/12, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 12/12, step 3/5: charge at 12A until 4.2V
# 2023-05-18 21:12:57.268 - [NOTICE] callbacks.on_step_start(180): Cycle 12/12, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 12/12, step 4/5: hold at 4.2V until C/50
# 2023-05-18 21:12:57.319 - [NOTICE] callbacks.on_step_start(180): Cycle 12/12, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 12/12, step 5/5: rest for 15 minute
# 2023-05-18 21:12:57.722 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 582.691 ms
# NOTICE:pybamm.logger:Finish experiment simulation, took 582.691 ms
# 2023-05-18 21:12:57.726 - [NOTICE] callbacks.on_cycle_start(172): Cycle 13/13 (146.142 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 13/13 (146.142 us elapsed) --------------------
# 2023-05-18 21:12:57.731 - [NOTICE] callbacks.on_step_start(180): Cycle 13/13, step 1/5: discharge at 0.8 A until 2.48V
# NOTICE:pybamm.logger:Cycle 13/13, step 1/5: discharge at 0.8 A until 2.48V
# 2023-05-18 21:12:57.824 - [NOTICE] callbacks.on_step_start(180): Cycle 13/13, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 13/13, step 2/5: rest for 15 minute
# 2023-05-18 21:12:57.838 - [NOTICE] callbacks.on_step_start(180): Cycle 13/13, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 13/13, step 3/5: charge at 12A until 4.2V
# 2023-05-18 21:12:57.858 - [NOTICE] callbacks.on_step_start(180): Cycle 13/13, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 13/13, step 4/5: hold at 4.2V until C/50
# 2023-05-18 21:12:57.908 - [NOTICE] callbacks.on_step_start(180): Cycle 13/13, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 13/13, step 5/5: rest for 15 minute
# 2023-05-18 21:12:58.316 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 589.428 ms
# NOTICE:pybamm.logger:Finish experiment simulation, took 589.428 ms
# 2023-05-18 21:12:58.322 - [NOTICE] callbacks.on_cycle_start(172): Cycle 14/14 (144.857 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 14/14 (144.857 us elapsed) --------------------
# 2023-05-18 21:12:58.326 - [NOTICE] callbacks.on_step_start(180): Cycle 14/14, step 1/5: discharge at 0.8 A until 2.48V
# NOTICE:pybamm.logger:Cycle 14/14, step 1/5: discharge at 0.8 A until 2.48V
# 2023-05-18 21:12:58.712 - [NOTICE] callbacks.on_step_start(180): Cycle 14/14, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 14/14, step 2/5: rest for 15 minute
# 2023-05-18 21:12:58.726 - [NOTICE] callbacks.on_step_start(180): Cycle 14/14, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 14/14, step 3/5: charge at 12A until 4.2V
# 2023-05-18 21:12:58.747 - [NOTICE] callbacks.on_step_start(180): Cycle 14/14, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 14/14, step 4/5: hold at 4.2V until C/50
# 2023-05-18 21:12:58.805 - [NOTICE] callbacks.on_step_start(180): Cycle 14/14, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 14/14, step 5/5: rest for 15 minute
# 2023-05-18 21:12:59.195 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 872.766 ms
# NOTICE:pybamm.logger:Finish experiment simulation, took 872.766 ms
# 2023-05-18 21:12:59.203 - [NOTICE] callbacks.on_cycle_start(172): Cycle 15/15 (168.118 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 15/15 (168.118 us elapsed) --------------------
# 2023-05-18 21:12:59.209 - [NOTICE] callbacks.on_step_start(180): Cycle 15/15, step 1/5: discharge at 0.8 A until 2.48V
# NOTICE:pybamm.logger:Cycle 15/15, step 1/5: discharge at 0.8 A until 2.48V
# 2023-05-18 21:12:59.301 - [NOTICE] callbacks.on_step_start(180): Cycle 15/15, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 15/15, step 2/5: rest for 15 minute
# 2023-05-18 21:12:59.316 - [NOTICE] callbacks.on_step_start(180): Cycle 15/15, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 15/15, step 3/5: charge at 12A until 4.2V
# 2023-05-18 21:12:59.337 - [NOTICE] callbacks.on_step_start(180): Cycle 15/15, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 15/15, step 4/5: hold at 4.2V until C/50
# 2023-05-18 21:12:59.392 - [NOTICE] callbacks.on_step_start(180): Cycle 15/15, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 15/15, step 5/5: rest for 15 minute
# 2023-05-18 21:12:59.903 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 699.490 ms
# NOTICE:pybamm.logger:Finish experiment simulation, took 699.490 ms
# 2023-05-18 21:12:59.908 - [NOTICE] callbacks.on_cycle_start(172): Cycle 16/16 (136.117 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 16/16 (136.117 us elapsed) --------------------
# 2023-05-18 21:12:59.912 - [NOTICE] callbacks.on_step_start(180): Cycle 16/16, step 1/5: discharge at 0.8 A until 2.48V
# NOTICE:pybamm.logger:Cycle 16/16, step 1/5: discharge at 0.8 A until 2.48V
# 2023-05-18 21:13:00.040 - [NOTICE] callbacks.on_step_start(180): Cycle 16/16, step 2/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 16/16, step 2/5: rest for 15 minute
# 2023-05-18 21:13:00.058 - [NOTICE] callbacks.on_step_start(180): Cycle 16/16, step 3/5: charge at 12A until 4.2V
# NOTICE:pybamm.logger:Cycle 16/16, step 3/5: charge at 12A until 4.2V
# 2023-05-18 21:13:00.086 - [NOTICE] callbacks.on_step_start(180): Cycle 16/16, step 4/5: hold at 4.2V until C/50
# NOTICE:pybamm.logger:Cycle 16/16, step 4/5: hold at 4.2V until C/50
# 2023-05-18 21:13:00.184 - [NOTICE] callbacks.on_step_start(180): Cycle 16/16, step 5/5: rest for 15 minute
# NOTICE:pybamm.logger:Cycle 16/16, step 5/5: rest for 15 minute
# 2023-05-18 21:13:00.841 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 932.236 ms
# NOTICE:pybamm.logger:Finish experiment simulation, took 932.236 ms
